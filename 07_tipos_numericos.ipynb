# %% [markdown]
# 1 - INT - inteiros

# %%
print ('inteiros')
print (1)
print (1 + 2)
# Out:
# inteiros
# 1
# 3

# %% [markdown]
# 2 - FLOAT - decimais

# %%
print ('Float - decimais')
print (1.3)
print (2.0 + 2.5)
print (4/2)
# Out:
# Float - decimais
# 1.3
# 4.5
# 2.0

# %% [markdown]
# 3 - Booleanos - verdadeiro / falso / comparações

# %%
print (True)
print (False)
print (bool(1))
print (bool(0))
# Out:
# True
# False
# True
# False
